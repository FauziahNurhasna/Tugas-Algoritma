# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Quests
#1. Menentukan persamaan kuadrat yang diketahui akar-akarnya
#2. Menentukan grafik fungsi kuadrat
#3. Menentukan titik puncak dan sumbu simetri
#4. Menentukan posisi titik puncak di kiri sumbu y, pada sumbu y(x,0), di kanan sumbu y
#5. Bagaimana posisi parabola memotong sumbu y (potong di sumbu y positif, y di pusat(0,0), sumbu y negatif)(depends on discriminant)
#6. Macam-macam akar persamaan kuadrat dilihat dari diskriminan
#7. Penyelesaian persamaan kuadrat dapat menggunakan rumus ABC
#8. Menyusun persamaan kuadrat baris jika diketahui akar-akarnya

#Kemungkinan D<0, D=0, D>0 dan a<0, a=0, a>0
#Display: Arah terbukanya kurva, titik puncak, titik puncak, posisi titik puncak terhadap sumbu y

#(x-a)(x-b) = x*x - bx - ax (-a)(-b)

# %%
#1. Menentukan persamaan kuadrat yang diketahui akar-akarnya
a = float(input('Masukkan akar pertama '))  #akar 1
b = float(input('Masukkan akar kedua ')) #akar 2

Sum = -(a + b)
Multi = a * b

if Multi > 0 and Sum > 0:
    print("Persamaan kuadratnya adalah x²+{:.2f}x+{:.2f}". format(Sum, Multi))
elif Multi > 0 and Sum < 0:
    print("Persamaan kuadratnya adalah x²{:.2f}x+{:.2f}". format(Sum, Multi))
elif Multi < 0 and Sum > 0:
    print('Persamaan kuadratnya adalah x²+{:.2f}x{:.2f}'. format(Sum, Multi))
elif Multi < 0 and Sum < 0:
    print('Persamaan kuadratnya adalah x²{:.2f}x{:.2f}'. format(Sum, Multi))
# Out:
# Masukkan akar pertama  -2
# Masukkan akar kedua  3
# Persamaan kuadratnya adalah x²-1.00x-6.00

# %%
import cmath
import numpy as np
import matplotlib.pyplot as plt

print("QUADRATIC EQUATION GRAPHIC")
print()

# Set while loop
repetition_27 = True
while repetition_27 == True:

    # Input parameters for the quadratic equation
    print("Please input the parameters for the quadratic equation")
    a_27 = float(input('Input the value of a '))
    b_27 = float(input('Input the value of b '))
    c_27 = float(input('Input the value of c '))
    print()

    # Determine whether it is a quadratic function or not
    if a_27 == 0:
        print("It is not a quadratic formula.")
    
    else:
    
        print("Here's a few info about the parabola:")
        if a_27 > 0:
            print("The function curves upward.")
        if a_27 < 0:
            print("The function curves downward.")
    
        D_27 = b_27 * b_27 - (4 * a_27 * c_27)  # Define Discriminant 
    
        # Use quadratic formula to find the roots
        x1_27 = (-b_27 + cmath.sqrt(D_27)) / (2 * a_27)  # first root
        x2_27 = (-b_27 - cmath.sqrt(D_27)) / (2 * a_27)  # second root
    
        # Vertex parameters
        xp_27 = -b_27 / (2 * a_27) 
        yp_27 = a_27 * (xp_27 ** 2) + b_27 * xp_27 + c_27 
    
        if b_27 == 0:
            print("The vertex is at the center of the y-axis.")
        elif b_27 > 0 and a_27 > 0:
            print("The vertex is to the left of the y-axis.")
        elif b_27 < 0 and a_27 > 0:
            print("The vertex is to the right of the y-axis.")  # Displaying where the vertex is to the y-axis
        elif b_27 > 0 and a_27 < 0:
            print("The vertex is to the right of the y-axis.")
        elif b_27 < 0 and a_27 < 0:
            print("The vertex is to the left of the y-axis.")
    
        if c_27 > 0:
            print("The function intercepts the y-axis in the positive y region.")
        elif c_27 == 0:
            print("The function intercepts the y-axis at the center.")  # displaying the position of the intersection with the y-axis
        else:
            print("The function intercepts the y-axis in the negative y region.")
        
        # Displaying various info about the quadratic equation
        print("Vertex coordinate: ({:.2f},{:.2f})".format(xp_27, yp_27))
        print('Axis of symmetry: x = {:.2f}'.format(xp_27))
        print("Y-intercept: (0,{:.2f})".format(c_27))
    
        # Input the roots to quadratic form to plot (setting the base)
        x_27 = np.linspace(xp_27 - 4, xp_27 + 4, 100)
        y_27 = a_27 * (x_27 ** 2) + b_27 * x_27 + c_27
    
        # Parabola plot
        plt.plot(x_27, y_27, color='green', label='{:.2f}x² + {:.2f}x + {:.2f}'.format(a_27, b_27, c_27))
        
        plt.axvline(x=xp_27, color='blue', linestyle='dashed', label='x = {:.2f}'.format(xp_27))  # axis of symmetry plot
        plt.legend(loc='upper left')  # Labels position
        plt.title("Quadratic Equation Graphic")
        plt.grid(True)  # grid plot
        plt.axvline(x=0, color='black')  # coordinate axes plot
        plt.axhline(y=0, color='black')
    
        # Extra elements based on discriminants (embellishments, I suppose)
        if D_27 > 0:
            print('The quadratic equation has two distinct real roots, namely x = {:.2f} and x = {:.2f}.'.format(x1_27.real, x2_27.real))
            print('Thus the parabola crosses the x-axis at two points.')
            plt.scatter([x1_27.real, x2_27.real], [0, 0], color='navy', s=60)
            plt.text(x1_27.real, 0, f'({x1_27.real:.2f}, 0)', ha='left', va='top', color='black')
            plt.text(x2_27.real, 0, f'({x2_27.real:.2f}, 0)', ha='right', va='top', color='black')

            plt.scatter([xp_27], [yp_27], color='red', s=60)
            plt.text(xp_27, yp_27, f'({xp_27:.2f}, {yp_27:.2f})', va='top', color='black')
    
            plt.show()
        
            Answer_27 = input('Do you want to try another problem?[Y/N]')
            if Answer_27.lower() == 'n':
                repetition_27 = False
        
        elif D_27 == 0:
            print('The quadratic equation has exactly one real root, namely x = {:.2f}.'.format(x1_27.real))
            print('Thus the parabola touches the x-axis at exactly one point.')
            plt.scatter([x1_27.real], [0], color='navy', s=60)
            plt.text(x1_27.real, 0, f'({x1_27.real:.2f}, 0)', ha='left', va='top', color='black')

            plt.scatter([xp_27], [yp_27], color='red', s=60)
            plt.text(xp_27, yp_27, f'({xp_27:.2f}, {yp_27:.2f})', va='top', color='black')
    
            plt.show()
            
            Answer_27 = input('Do you want to try another problem?[Y/N]')
            if Answer_27.lower() == 'n':
                repetition_27 = False
        
        elif D_27 < 0:
            print('The quadratic equation has two complex (non-real) roots, namely x = {:.2f} and x = {:.2f}.'.format(x1_27.real, x2_27.real))
            print('Thus the parabola does not intersect the x-axis at all.')
            plt.scatter([xp_27], [yp_27], color='red', s=60)
            plt.text(xp_27, yp_27, f'({xp_27:.2f}, {yp_27:.2f})', va='top', color='black')
    
            plt.show()
            
            Answer_27 = input('Do you want to try another problem?[Y/N]')
            if Answer_27.lower() == 'n':
                repetition_27 = False
# Out:
# QUADRATIC EQUATION GRAPHIC
#
# Please input the parameters for the quadratic equation
# Input the value of a  1
# Input the value of b  4
# Input the value of c  4
# Here's a few info about the parabola:
# The function curves upward.
# The vertex is to the left of the y-axis.
# The function intercepts the y-axis in the positive y region.
# Vertex coordinate: (-2.00,0.00)
# Axis of symmetry: x = -2.00
# Y-intercept: (0,4.00)
# The quadratic equation has exactly one real root, namely x = -2.00.
# Thus the parabola touches the x-axis at exactly one point.
# Do you want to try another problem?[Y/N] Y
# Please input the parameters for the quadratic equation
# Input the value of a  1
# Input the value of b  -3
# Input the value of c  9
# Here's a few info about the parabola:
# The function curves upward.
# The vertex is to the right of the y-axis.
# The function intercepts the y-axis in the positive y region.
# Vertex coordinate: (1.50,6.75)
# Axis of symmetry: x = 1.50
# ...

# %%
#3.Menentukan titik puncak dan sumbu simetri
#4.Menentukan posisi titik  puncak terhadap sumbu y
a = 1
b = 9
c = 18

D = (b*b) - (4*a*c)

xp = -b/(2*a)
yp = -D/(4*a)
#Titik puncak ada di y pusat (0,0) jika b = 0
#Titik puncak ada di kiri sumbu y jika a dan b sama tanda
#titikpuncak ada di kanan sumbu y jika a dan b sama tanda
print("Titik puncaknya adalah({:.2f},{:.2f})". format(xp, yp))
print("Sumbu simetrinya adalah x={:.2f}". format(xp)) #sumbu simetri = xp
# Out:
# Titik puncaknya adalah(-4.50,-2.25)
# Sumbu simetrinya adalah x=-4.50

# %%
import matplotlib.pyplot as plt

# Coordinates for the two points
x = [1, 3]  # x-coordinates
y = [2, 4]  # y-coordinates

# Create the scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Two Points')

# Annotate each point with its coordinates
for (i, j) in zip(x, y):
    plt.text(i, j, f"({i}, {j})", ha='right', va='bottom')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Rentang x untuk grafik parabola
x = np.linspace(-10, 10, 400)

# 1. Parabola memotong sumbu y di posisi positif (contoh: y = x^2 + 2)
y1 = x**2 + 2

# 2. Parabola memotong sumbu y di pusat (0,0) (contoh: y = x^2)
y2 = x**2

# 3. Parabola memotong sumbu y di posisi negatif (contoh: y = x^2 - 3)
y3 = x**2 - 3

plt.figure(figsize=(18, 5))

# Plot 1
plt.subplot(1, 3, 1)
plt.plot(x, y1, label='y = x^2 + 2')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('Parabola memotong sumbu y di posisi positif')
plt.legend()

# Plot 2
plt.subplot(1, 3, 2)
plt.plot(x, y2, label='y = x^2')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('Parabola memotong sumbu y di pusat (0,0)')
plt.legend()

# Plot 3
plt.subplot(1, 3, 3)
plt.plot(x, y3, label='y = x^2 - 3')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('Parabola memotong sumbu y di posisi negatif')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import cmath
import numpy as np
import matplotlib.pyplot as plt

# Input a, b, c
a = float(input('Input the value of a: '))
b = float(input('Input the value of b: '))
c = float(input('Input the value of c: '))

# Determine whether a is a quadratic function or not
if a == 0:
    print("It is not a quadratic formula.")
else:
    D = b*b - (4*a*c)  # Define Discriminant 
    # Use ABC formula to find the roots
    x1 = (-b + cmath.sqrt(D)) / (2*a)  # first root
    x2 = (-b - cmath.sqrt(D)) / (2*a)  # second root
    xp = -b / (2*a)  # function for the vertex
    yp = a * (xp**2) + b * xp + c  # y-coordinate of the vertex
    
    # Generate points to plot the quadratic function
    x = np.linspace(xp - 3, xp + 3, 100)
    y = a * (x**2) + b * x + c
    
    # Plot the quadratic equation
    plt.plot(x, y, color='green')
    
    # Add title and grid
    plt.title("Grafik persamaan kuadrat")
    plt.grid(True)
    
    # Plot the x and y axis
    plt.axvline(x=0, color='black')
    plt.axhline(y=0, color='black')
    
    # Scatter the roots on the x-axis
    plt.scatter([x1.real, x2.real], [0, 0], color='navy', s=60)
    
    # Annotate the roots
    plt.text(x1.real, 0, f'({x1.real:.2f}, 0)', ha='left', va='top', color='black')
    plt.text(x2.real, 0, f'({x2.real:.2f}, 0)', ha='right', va='top', color='black')
    
    # Scatter and annotate the vertex
    plt.scatter([xp], [yp], color='red', s=60)
    plt.text(xp, yp, f'({xp:.2f}, {yp:.2f})', va='top', color='black')
    
    # Show the plot
    plt.show()
# Out:
# Input the value of a:  1
# Input the value of b:  9
# Input the value of c:  18
