# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
InstitutionName_27 = "Easton Magic Academy"


print("Welcome, traveler. On this fine day, let me take you on a little adventure.")
print("What should I call you?")
CharacterName_27 = input("Your name:")
print("Come sit, " + CharacterName_27 + ". Drink this potion as you listen to my voice and let your imaginations run wild.")
WaterTaste_27 = input("What does the potion taste like?:")
print("What? You think it taste like " + WaterTaste_27 + "? Weird, I definitely bought it from a trusted, nonsuspicious merchant.")
print("Anyways, this story takes place in a world where magic is considered the norm. Everyone, well, almost everyone possess some sort of magic power.")
print("You're applying to a magic school called " + InstitutionName_27 + ".")
print("As you walk by the entrance, you saw the shining plate of ") 
print(InstitutionName_27[0:6].upper() + InstitutionName_27[12:20].upper())
print()

print("(you drift into unconciousness as you listen to the new stranger you just met)")
print("(All of a sudden, you woke up in a room)")
print()

print('"Hey, ' + CharacterName_27 + '! Wake up! We are going to be late to our study session!"')
Response1_27 = input('Your reaction: ')
print('"No time, come on!"')
print("You hurriedly do as he says, seeing as he is wearing a robe, you do the same before going to your 'study session'")
print("It is a math study session. You work with that person you seemingly just met and 4 other people")
print("The one with a bowlcut hair murmurs, ")
print('"Hmm, 12 x 13. That would be"')
MathAnswer_27 = 12 * 13 + 273
print('" ' + str(MathAnswer_27) + '! Right, ' + CharacterName_27 + '?"')
print("Before you could say anything, a blue haired boy answered, ")
print('"Not even close, Mash. The answer is ' + (str(12*13)) + '."')
print("Then the blue haired boy turn his attention to you")
print('"Whats up, ' + CharacterName_27 + '? Are you sick?"')
Answer1_27 = input("Your response: ")
print(Answer1_27 + '? You seem really out of it' )
print("Mash: I call it quits, Lance. " + CharacterName_27 + ", Let's go buy creampuff with me.")
Answer2_27 = input("Your answer: ")
print("Mash:" + Answer2_27 + "? Well, you're coming with me either way.")
print()

print("You stood in front of the shop. You look into your coin pouch, you have 100 drago coins.")
Coins_27 = input("One creampuff costs 3 coins. How much coins are you going to use?:")
CreampuffAmount_27 = int(Coins_27) // 3
Change_27 = int(Coins_27) % 3
CoinsLeft_27 = 100 - (int(CreampuffAmount_27) * 3)
print("You obtained " + str(CreampuffAmount_27) + " creampuffs! And your change is " + str(Change_27) + " coins. So now you have " + str(CoinsLeft_27) + " Drago coins left.")
print()

print("In the distance, you see a stall of your favorite food.")
FavoriteFood_27 = input("What kind of stall is it?:")
print("Mash: Hm? I see you staring. Do you want to eat " + FavoriteFood_27 + "? Let's buy some.")
print("You two approach the stall. Once again, you look into your coin pouch.")
print()

print("You have " + str(CoinsLeft_27) + " Drago coins. One " + FavoriteFood_27 + " costs 6 coins.")
Coins2_27 = input("How much coins are you going to use?:")
FavFoodAmount_27 = int(Coins2_27) // 6
Change2_27 = int(Coins2_27) % 6
CoinsLeft2_27 = int(CoinsLeft_27) - (int(FavFoodAmount_27) * 6)
print("You obtained " + str(FavFoodAmount_27) + " " + FavoriteFood_27 + "! And your change is " + str(Change2_27) + " coins. So now you have " + str(CoinsLeft2_27) + " Drago coins left.")
print()

MashCoins_27 = int(10)
print("Mash: Let's play a game. Is it true that you have more than 50 coins left?")
print("You think to yourself, is it?")
print(CoinsLeft2_27 > 50)
print()
 
print('"Why does it matter if I have more than 50 coins left?"')
print("Mash: I just remembered we need a few mandrake plants for tomorrow's lesson.")
print("Mash: I spent too much of my coins on creampuff. I only have " + str(MashCoins_27) + " coins left.")
print("Mash: One mandrake is pretty expensive already. It cost around 30 coins.")
print("Mash: I wonder if we should buy it while we're here.")
print("Mash: You haven't bought one either, have you?")
print()

print("You once again think to yourself. Is it true that you can buy one mandrake each for the both of you?")
print( MashCoins_27 == 10 and CoinsLeft2_27 >= 50 )
print()

print("Mash: Then again, I think we could just ask Lance for that. He should have a few stocks.")
print("Mash: Let's save our money, and let's go back to our dorm.")
print("Mash: We've been gone for some time. They're probably waiting.")
print()

print("As you walk back, you wonder. How long will you be here? And where would it take you?")
# Out:
# Welcome, traveler. On this fine day, let me take you on a little adventure.
# What should I call you?
# Your name: Fau
# Come sit, Fau. Drink this potion as you listen to my voice and let your imaginations run wild.
# What does the potion taste like?: mud
# What? You think it taste like mud? Weird, I definitely bought it from a trusted, nonsuspicious merchant.
# Anyways, this story takes place in a world where magic is considered the norm. Everyone, well, almost everyone possess some sort of magic power.
# You're applying to a magic school called Easton Magic Academy.
# As you walk by the entrance, you saw the shining plate of
# EASTON ACADEMY
#
# (you drift into unconciousness as you listen to the new stranger you just met)
# (All of a sudden, you woke up in a room)
#
# "Hey, Fau! Wake up! We are going to be late to our study session!"
# Your reaction:  Why
# "No time, come on!"
# ...
