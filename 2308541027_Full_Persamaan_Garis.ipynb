# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#importing numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

print("Hello there, fine lad.")
banter_27 = input("Could it be that you need my assistance with a line equation problem?[Y/N]")
if banter_27 == "Y" or banter_27 == "y":
    print("Haha, I thought so. Then, ")
elif banter_27 == "N" or banter_27 == "n":
    print("Come on now, don't be coy. Asking for help isn't a bad thing.")
    print("Let us just continue our business then.")
else:
    print("My creator isn't diligent enough to make me respond to other answers, lad.")
    print("Though we should proceed still. Otherwise, why would you run this code, eh?")

#set while loop
repetition_27 = True

while repetition_27 == True:

    print()
    print("[1] Each line will pass through two known points")
    print("[2] Each line has a known gradient and the points it passes through")
    print("[3] Both lines satisfy equations of the form ax+by=c and dx+ey=f")
    Cases_27 = input("Which case are we working with, boss?")
    print()

    if Cases_27 == '1':
        print("Got it. Please give me these informations:")
        # User inputs the coordinates for the first line and the second line
        print("Coordinates for the first line.")
        print("Input coordinate for the first point:")
        a_27 = float(input("x coordinate:")) #for (a,b) 
        b_27 = float(input('y coordinate:'))
        print("Input coordinates for the second point:")
        c_27 = float(input("x coordinate:")) #for (c.d)
        d_27 = float(input("y coordinate:"))
        print()

        print("Coordinates for the second line.")
        print("Input coordinate for the first point:")
        e_27 = float(input("x coordinate:")) #for (e,f)
        f_27 = float(input("y coordinate:"))
        print("Input coordinates for the second point:")
        g_27 = float(input("x coordinate:")) #for (g,h) 
        h_27 = float(input("y coordinate:"))

        #Using equations to define the gradients and the points it passes through
        m1_27 = (d_27 - b_27) / (c_27 - a_27) #first gradient
        m2_27 = (h_27 - f_27) / (g_27 - e_27) #second gradient
        c1_27 = b_27 - m1_27 * a_27 #first intercept
        c2_27 = f_27 - m2_27 * e_27 #second intercept

        #Inserting the previous gradients and intercepts value to a standard form for line equation mx+c
        print()
        if c1_27 > 0:
            print("The line equation for the first line is y={:.2f}x+{:.2f} ". format(m1_27,c1_27))
        else:
            print("The line equation for the first line is y={:.2f}x{:.2f}". format(m1_27,c1_27))
        print("Thus, the gradient for the first line is {:.2f}". format(m1_27))
        print()
        if c2_27 > 0:
            print("The line equation for the second line is y={:.2f}x+{:.2f} ". format(m2_27,c2_27))
        else:
            print("The line equation for the second line is y={:.2f}x{:.2f}". format(m2_27,c2_27))
        print("Thus, the gradient for the second line is {:.2f}". format(m2_27))
        print()

        #Using if-else function to check whether the two lines are coincident, parallel, or intersect
        if m1_27 == m2_27 and c1_27 == c2_27:
            print("The two lines are coincident.")
            x_27 = np.linspace(-5, 5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', linestyle='dashed', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', linestyle='dashed', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show() 
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
        elif m1_27 == m2_27 and c1_27 != c2_27:
            print("The two lines are parallel.")
            x_27 = np.linspace(-5, 5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show() 
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
        else:
            print("The two lines intersect.")
           #defining the intersection
            TPx_27 = (c2_27 - c1_27) / (m1_27 - m2_27)
            TPy_27 = m1_27 * TPx_27 + c1_27
    
            print("Its intersection point is ({:.2f},{:.2f})". format(TPx_27,TPy_27))
            x_27 = np.linspace(TPx_27-5, TPx_27+5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.plot(TPx_27,TPy_27, color='blue', marker='o', markersize=7)
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show()
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
        
    elif Cases_27 == '2':
        print("Understood. Then I kindly ask that you provide these informations:")
        m1_27 = float(input("Gradient of the first line ")) #first gradient
        a_27 = float(input("The x value of the point passed by the first line ")) #for (a,b)
        b_27= float(input("The y value of the point passed by the first line "))
        print()
    
        m2_27 = float(input("Gradient of the second line ")) #second gradient
        c_27 = float(input("The x value of the point passed by the second line ")) #for (c,d)
        d_27= float(input("The y value of the point passed by the second line "))
    
        c1_27 = b_27-m1_27*a_27 #first intercept
        c2_27 = d_27-m2_27*c_27 #second intercept
        print()
    
        print('So to reasses the information you have given to me,' )
        if c1_27 > 0:
            print("The line equation for the first line is y={:.2f}x+{:.2f} ". format(m1_27,c1_27))
        else:
            print("The line equation for the first line is y={:.2f}x{:.2f}". format(m1_27,c1_27))
        print("Thus, the gradient for the first line is {:.2f}". format(m1_27))
        print()
        if c2_27 > 0:
            print("The line equation for the second line is y={:.2f}x+{:.2f} ". format(m2_27,c2_27))
        else:
            print("The line equation for the second line is y={:.2f}x{:.2f}". format(m2_27,c2_27))
        print("Thus, the gradient for the second line is {:.2f}". format(m2_27))
        print()

        #Using if-else function to check whether the two lines are coincident, parallel, or intersect
        if m1_27 == m2_27 and c1_27 == c2_27:
            print("The two lines are coincident.")
            x_27 = np.linspace(-5, 5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', linestyle='dashed', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', linestyle='dashed', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show() 
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
        elif m1_27 == m2_27 and c1_27 != c2_27:
            print("The two lines are parallel.")
            x_27 = np.linspace(-5, 5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show() 
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
        else:
            print("The two lines intersect.")
            #defining the intersection
            TPx_27 = (c2_27 - c1_27) / (m1_27 - m2_27)
            TPy_27 = m1_27 * TPx_27 + c1_27
    
            print("Its intersection point is ({:.2f},{:.2f})". format(TPx_27,TPy_27))
            x_27 = np.linspace(TPx_27-5, TPx_27+5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.plot(TPx_27,TPy_27, color='blue', marker='o', markersize=7)
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show()
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
    elif Cases_27 == '3':
        print("Roger that. Now if you would please give me these informations")
        a_27=float(input("The coefficient of x on the first line "))
        b_27=float(input("The coefficient of y on the first line "))
        c_27=float(input("The constant of the first line "))
    
        d_27=float(input("The coefficient of x on the second line "))
        e_27=float(input("The coefficient of y on the second line "))
        f_27=float(input("The constant of the second line "))
    
        m1_27 = (-a_27)/b_27 #first gradient
        m2_27 = (-d_27)/e_27 #second gradient
    
        c1_27 = c_27/b_27 #first intercept
        c2_27 = f_27/e_27 #second intercept
        print()
    
        print('Here are a few informations based on my analysis.' )
        if c1_27 > 0:
            print("The line equation for the first line is y={:.2f}x+{:.2f} ". format(m1_27,c1_27))
        else:
            print("The line equation for the first line is y={:.2f}x{:.2f}". format(m1_27,c1_27))
        print("Thus, the gradient for the first line is {:.2f}". format(m1_27))
        print()
        if c2_27 > 0:
            print("The line equation for the second line is y={:.2f}x+{:.2f} ". format(m2_27,c2_27))
        else:
            print("The line equation for the second line is y={:.2f}x{:.2f}". format(m2_27,c2_27))
        print("Thus, the gradient for the second line is {:.2f}". format(m2_27))
        print()

        #Using if-else function to check whether the two lines are coincident, parallel, or intersect
        if m1_27 == m2_27 and c1_27 == c2_27:
            print("The two lines are coincident.")
            x_27 = np.linspace(-5, 5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', linestyle='dashed', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', linestyle='dashed', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show() 
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
        elif m1_27 == m2_27 and c1_27 != c2_27:
            print("The two lines are parallel.")
            x_27 = np.linspace(-5, 5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show() 
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
        else:
            print("The two lines intersect.")
            #defining the intersection
            TPx_27 = (c2_27 - c1_27) / (m1_27 - m2_27)
            TPy_27 = m1_27 * TPx_27 + c1_27
    
            print("Its intersection point is ({:.2f},{:.2f})". format(TPx_27,TPy_27))
            x_27 = np.linspace(TPx_27-5, TPx_27+5, 100)
            if c1_27 > 0:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
            else:
                plt.plot(x_27, m1_27 * x_27 + c1_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
            if c2_27 > 0:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
            else:
                plt.plot(x_27, m2_27 * x_27 + c2_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
            plt.plot(TPx_27,TPy_27, color='blue', marker='o', markersize=7)
            plt.title("Image of the line equations") #add title
            plt.grid(True) #add grid
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.legend(loc='best') #add line information
            plt.show()
            print()
            Answer_27= input("Would you like to know something else?[Y/N]:")
            if (Answer_27 == "N" or Answer_27 == "n"):
                break
                (repetition == False)
    
    else:
        print("I know making decisions can be hard, you can't help but to avoid it sometimes.")
        print("But you really need to pick just either 1, 2, or 3. Nothing else, okay?")
        print("Try again. Choose correctly this time")
        print()
# Out:
# Hello there, fine lad.
# Could it be that you need my assistance with a line equation problem?[Y/N] N
# Come on now, don't be coy. Asking for help isn't a bad thing.
# Let us just continue our business then.
#
# [1] Each line will pass through two known points
# [2] Each line has a known gradient and the points it passes through
# [3] Both lines satisfy equations of the form ax+by=c and dx+ey=f
# Which case are we working with, boss? 2
# Understood. Then I kindly ask that you provide these informations:
# Gradient of the first line  -3
# The x value of the point passed by the first line  2
# The y value of the point passed by the first line  5
# Gradient of the second line  6
# The x value of the point passed by the second line  -1
# The y value of the point passed by the second line  -4
# So to reasses the information you have given to me,
# The line equation for the first line is y=-3.00x+11.00
# Thus, the gradient for the first line is -3.00
#
# ...
