# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#importing numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

#User inputs the coordinates for the first line and the second line
print("Coordinates for the first line.")
print("Input coordinate for the first point:")
a_27 = int(input("x coordinate:")) #for (a,b) 
b_27 = int(input('y coordinate:'))
print("Input coordinates for the second point:")
c_27 = int(input("x coordinate:")) #for (c.d)
d_27 = int(input("y coordinate:"))
print()

print("Coordinates for the second line.")
print("Input coordinate for the first point:")
e_27 = int(input("x coordinate:")) #for (e,f)
f_27 = int(input("y coordinate:"))
print("input coordinates for the second point")
g_27 = int(input("x coordinate:")) #for (g,h) 
h_27 = int(input("y coordinate:"))

#Using equations to define the gradients and constants
m1_27 = (d_27 - b_27) / (c_27 - a_27)
m2_27 = (h_27 - f_27) / (g_27 - e_27)
c1_27 = b_27 - m1_27 * a_27
c2_27 = f_27 - m2_27 * e_27

#inserting the previous gradients and constants value to a standard form for line equation and printing it
print()
if c1_27 > 0:
    print("The line equation for the first line is y={:.2f}x+{:.2f} ". format(m1_27,c1_27))
else:
    print("The line equation for the first line is y={:.2f}x{:.2f}". format(m1_27,c1_27))
print("Thus, the gradient for the second line is {:.2f}". format(m1_27))
print()
if c2_27 > 0:
    print("The line equation for the second line is y={:.2f}x+{:.2f} ". format(m2_27,c2_27))
else:
    print("The line equation for the second line is y={:.2f}x{:.2f}". format(m2_27,c2_27))
print("Thus, the gradient for the second line is {:.2f}". format(m2_27))
print()

#Using if-else function to check whether the two lines are coincident,parallel,or intersect
if m1_27 == m2_27 and c1_27 == c2_27:
    print("The two lines are coincident.")
    x_27 = np.arange(-100,100,0.01)
    if c1_27 > 0:
        plt.plot(x_27, m1_27 * (x_27 - a_27) + b_27, color="green", label='y={:.2f}x+{:.2f}'. format(m1_27,c1_27))
    else:
        plt.plot(x_27, m1_27 * (x_27 - a_27) + b_27, color='green', label='y={:.2f}x{:.2f}'. format(m1_27,c1_27))
    if c2_27 > 0:
        plt.plot(x_27, m2_27 * (x_27 - e_27) + f_27, color="orange", label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
    else:
        plt.plot(x_27, m2_27 * (x_27 - e_27) + f_27, color="orange", label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
    plt.legend(loc='best')
    plt.show() 
    
elif m1_27 == m2_27 and c1_27 != c2_27:
    print("The two lines are parallel.")
    x_27 = np.arange(-100,100,0.01)
    if c1_27 > 0:
        plt.plot(x_27, m1_27 * (x_27 - a_27) + b_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
    else:
        plt.plot(x_27, m1_27 * (x_27 - a_27) + b_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
    if c2_27 > 0:
        plt.plot(x_27, m2_27 * (x_27 - e_27) + f_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
    else:
        plt.plot(x_27, m2_27 * (x_27 - e_27) + f_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
    plt.legend(loc='best')
    plt.show()
    
else:
    print("The two lines intersect.")
    #defining the intersection
    TPx_27 = (c2_27 - c1_27) / (m1_27 - m2_27)
    TPy_27 = m1_27 * TPx_27 + c1_27
    
    print("Its intersection point is ({:.2f},{:.2f})". format(TPx_27,TPy_27))
    x_27 = np.arange(-100,100,0.01)
    if c1_27 > 0:
        plt.plot(x_27, m1_27 * (x_27 - a_27) + b_27, color='green', label='y={:.2f}x+{:.2f}'.format(m1_27,c1_27))
    else:
        plt.plot(x_27, m1_27 * (x_27 - a_27) + b_27, color='green', label='y={:.2f}x{:.2f}'.format(m1_27,c1_27))
    if c2_27 > 0:
        plt.plot(x_27, m2_27 * (x_27 - e_27) + f_27, color='orange', label='y={:.2f}x+{:.2f}'. format(m2_27,c2_27))
    else:
        plt.plot(x_27, m2_27 * (x_27 - e_27) + f_27, color='orange', label='y={:.2f}x{:.2f}'. format(m2_27,c2_27))
    plt.plot(TPx_27,TPy_27, color='blue', marker='o', markersize=7)
    plt.legend(loc='best')
    plt.show()
# Out:
# Coordinates for the first line.
# Input coordinate for the first point:
# x coordinate: 5
# y coordinate: -6
# Input coordinates for the second point:
# x coordinate: 11
# y coordinate: 7
# Coordinates for the second line.
# Input coordinate for the first point:
# x coordinate: 2
# y coordinate: -8
# input coordinates for the second point
# x coordinate: -9
# y coordinate: -3
# The line equation for the first line is y=2.17x-16.83
# Thus, the gradient for the second line is 2.17
#
# The line equation for the second line is y=-0.45x-7.09
# Thus, the gradient for the second line is -0.45
#
# The two lines intersect.
# Its intersection point is (3.72,-8.78)
