# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("Hello, do you think you have a good general knowledge? Let's find out by taking this trivia!")
print("Don't cheat, okay? No searching on your first attempt.")
print("Well then, let's start!")

repetition = True
while repetition == True:
    
    print()
    print("1. Who was the first person that went out to space?")
    print("[a]John Glenn")
    print("[b]Yuri Gagarin")
    print("[c]Neil Armstrong")
    print("[d]Buzz Aldrin")
    Answer1_27 = input("Your answer:")
    Points_27 = 0
    Points1_27 = 0

    if Answer1_27 == 'b' or Answer1_27 == 'B':
        Points1_27 = Points_27 + 1
    elif Answer1_27 == 'a' or Answer1_27 == 'A':
        Points1_27 = Points_27 + 0
    elif Answer1_27 == 'c' or Answer1_27 == 'C':
        Points1_27 = Points_27 + 0
    elif Answer1_27 == 'd' or Answer1_27 == 'D':
        Points1_27 = Points_27 + 0
    print()

    print("2. What language is used in Brazil?")
    print("[a]English")
    print("[b]Spanish")
    print("[c]Portuguese")
    print("[d]French")
    Answer1_27 = input("Your answer:")
    Points2_27 = 0

    if Answer1_27 == 'c' or Answer1_27 == 'C':
        Points2_27 = Points1_27 + 1
    elif Answer1_27 == 'a' or Answer1_27 == 'A':
        Points2_27 = Points1_27 + 0
    elif Answer1_27 == 'b' or Answer1_27 == 'B':
        Points2_27 = Points1_27 + 0
    elif Answer1_27 == 'd' or Answer1_27 == 'D':
        Points2_27 = Points1_27 + 0
    print()

    print("3. Who discovered electricity?")
    print("[a]Benjamin Franklin")
    print("[b]Michael Faraday")
    print("[c]Nikola Tesla")
    print("[d]Isaac Newton")
    Answer1_27 = input("Your answer:")
    Points3_27 = 0

    if Answer1_27 == 'a' or Answer1_27 == 'A':
        Points3_27 = Points2_27 + 1
    elif Answer1_27 == 'c' or Answer1_27 == 'C':
        Points3_27 = Points2_27 + 0
    elif Answer1_27 == 'b' or Answer1_27 == 'B':
        Points3_27 = Points2_27 + 0
    elif Answer1_27 == 'd' or Answer1_27 == 'D':
        Points3_27 = Points2_27 + 0
    print()

    print("4. What is the capital of Australia?")
    print("[a]Canberra")
    print("[b]Brisbane")
    print("[c]Sydney")
    print("[d]Melbourne")
    Answer1_27 = input("Your answer:")
    Points4_27 = 0

    if Answer1_27 == 'a' or Answer1_27 == 'A':
        Points4_27 = Points3_27 + 1
    elif Answer1_27 == 'c' or Answer1_27 == 'C':
        Points4_27 = Points3_27 + 0
    elif Answer1_27 == 'b' or Answer1_27 == 'B':
        Points4_27 = Points3_27 + 0
    elif Answer1_27 == 'd' or Answer1_27 == 'D':
        Points4_27 = Points3_27 + 0
    print()

    print("5. In what year was Facebook founded?")
    print("[a]2000")
    print("[b]2005")
    print("[c]2008")
    print("[d]2004")
    Answer1_27 = input("Your answer:")
    Points5_27 = 0

    if Answer1_27 == 'd' or Answer1_27 == 'D':
        Points5_27 = Points4_27 + 1
    elif Answer1_27 == 'c' or Answer1_27 == 'C':
        Points5_27 = Points4_27 + 0
    elif Answer1_27 == 'b' or Answer1_27 == 'B':
        Points5_27 = Points4_27 + 0
    elif Answer1_27 == 'a' or Answer1_27 == 'A':
        Points5_27 = Points4_27 + 0
    print()

    print("6. What are the main gases found in the earth's atmosphere?")
    print("[a]Oxygen")
    print("[b]Argon")
    print("[c]Nitrogen")
    print("[d]Carbon dioxide")
    Answer1_27 = input("Your answer:")
    Points6_27 = 0

    if Answer1_27 == 'c' or Answer1_27 == 'C':
        Points6_27 = Points5_27 + 1
    elif Answer1_27 == 'd' or Answer1_27 == 'D':
        Points6_27 = Points5_27 + 0
    elif Answer1_27 == 'b' or Answer1_27 == 'B':
        Points6_27 = Points5_27 + 0
    elif Answer1_27 == 'a' or Answer1_27 == 'A':
        Points6_27 = Points5_27 + 0
    print()

    print("7. What is the largest country in the world by area?")
    print("[a]China")
    print("[b]Russia")
    print("[c]America")
    print("[d]India")
    Answer1_27 = input("Your answer:")
    Points7_27 = 0

    if Answer1_27 == 'b' or Answer1_27 == 'B':
        Points7_27 = Points6_27 + 1
    elif Answer1_27 == 'd' or Answer1_27 == 'D':
        Points7_27 = Points6_27 + 0
    elif Answer1_27 == 'c' or Answer1_27 == 'C':
        Points7_27 = Points6_27 + 0
    elif Answer1_27 == 'a' or Answer1_27 == 'A':
        Points7_27 = Points6_27 + 0
    print()

    print("8. In which city is the United Nation's headquarters?")
    print("[a]Jenewa, Swiss")
    print("[b]Paris, France")
    print("[c]Wina, Austria")
    print("[d]New York, US")
    Answer1_27 = input("Your answer:")
    TotalPoints_27 = 0

    if Answer1_27 == 'd' or Answer1_27 == 'D':
        TotalPoints_27 = Points7_27 + 1
    elif Answer1_27 == 'b' or Answer1_27 == 'B':
        TotalPoints_27 = Points7_27 + 0
    elif Answer1_27 == 'c' or Answer1_27 == 'C':
        TotalPoints_27 = Points7_27 + 0
    elif Answer1_27 == 'a' or Answer1_27 == 'A':
        TotalPoints_27 = Points7_27 + 0

    print()
    print('You got ' + str(TotalPoints_27) + '/8 answers correct.')
    if TotalPoints_27 == 8:
        print("You got perfect score!")
    if TotalPoints_27 == 7:
        print("You almost got it! Maybe you could try one more time?")
    if 4 <= TotalPoints_27 <= 6:
        print("Not bad. You're pretty knowledgeable.")
    if TotalPoints_27 < 4:
        print("Maybe you could consider reading more?")

    print()
    Answer_27= input("Would you like to try again?[Y/N]:")
    if (Answer_27 == "N" or Answer_27 == "n"):
            break
            (repetition == False)
# Out:
# Hello, do you think you have a good general knowledge? Let's find out by taking this trivia!
# Don't cheat, okay? No searching on your first attempt.
# Well then, let's start!
#
# 1. Who was the first person that went out to space?
# [a]John Glenn
# [b]Yuri Gagarin
# [c]Neil Armstrong
# [d]Buzz Aldrin
# Your answer: b
# 2. What language is used in Brazil?
# [a]English
# [b]Spanish
# [c]Portuguese
# [d]French
# Your answer: c
# 3. Who discovered electricity?
# [a]Benjamin Franklin
# [b]Michael Faraday
# [c]Nikola Tesla
# [d]Isaac Newton
# Your answer: a
# 4. What is the capital of Australia?
# [a]Canberra
# [b]Brisbane
# [c]Sydney
# [d]Melbourne
# Your answer: a
# 5. In what year was Facebook founded?
# [a]2000
# [b]2005
# [c]2008
# [d]2004
# Your answer: d
# 6. What are the main gases found in the earth's atmosphere?
# [a]Oxygen
# [b]Argon
# [c]Nitrogen
# [d]Carbon dioxide
# Your answer: c
# 7. What is the largest country in the world by area?
# [a]China
# [b]Russia
# [c]America
# ...
